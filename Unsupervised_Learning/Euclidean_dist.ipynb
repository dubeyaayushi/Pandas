# %%
#! Euclidean distance ka matlab hai:

# Do points ke beech ka seedha (straight-line) distance


#! 🎯 Euclidean Distance Hume Batata Kya Hai?

# ! Euclidean distance batata hai:

# Do data points ek dusre se kitne similar ya different hain.

#! Simple language me:

# ✔ Distance kam → Points similar
# ✔ Distance zyada → Points different



#? 🧠 Example 1 (Student Data)

# Man lo 2 students:

# Student A: (Hours=2, Score=50)
# Student B: (Hours=3, Score=52)

# Distance small aayega.

# 👉 Matlab dono similar type ke students hain.
