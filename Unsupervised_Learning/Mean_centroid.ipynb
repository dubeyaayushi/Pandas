# %%
    # ! Centroid
    #  the centroid is the geometric center of a cluster, calculated as the arithmetic mean (average) of all data points assigned to that cluster. The algorithm iteratively moves these centroids to minimize the distance between data points and their closest center.
     
    # ! Centroid: The center point (or prototype) of a cluster. It represents the "mean" location of all data points within that specific group.

# %%
# Where do we use the mean and clustering ?

# it is use to find the group of similar data points or to cluster the data 
 
# ! Mean Kya Hota Hai?

# Mean ka matlab hota hai:

# Average value

#! 🔹 Simple Example
# Man lo 3 students ke study hours:

# [2, 4, 6]
# Mean:
# (2+4+6)/3=4
# 👉 Average hours = 4

# %%
#! 🎯 2️⃣ Centroid Kya Hota Hai?

# Centroid ka matlab hota hai:

# Ek group (cluster) ka center point

# Matlab:

# Agar 2D data hai (x, y),
# to centroid = us group ke sab points ka mean.

# %%
# Example (2D Data)
# Man lo 3 students ke:

# Hours	Score
# 2	    50
# 4	    60
# 6	    70
# Centroid nikalne ke liye:

# Hours ka mean:
# (2+4+6)/3=4
# Score ka mean:
# (50+60+70)/3=60
# 👉 Centroid = (4, 60)
