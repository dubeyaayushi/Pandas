# %%
  
# ?  the very basic of unsupervised learning is knowing about the basics and that is 
# !  Clustering
#   basically clustering is grouping similar type of data or things together without a lable or somehthing 

# clustering is the part of unspervised leaning model khud clusters form karega the comman algorithm which we use for it is K-means  

#clustering does not predict the value it just groups the similar data points together

#model learns from the patterns
