# %%
# Linear Regression

from sklearn.linear_model import LinearRegression

X = [[1], [2], [3], [4], [5]]
y = [40, 50, 60, 70, 80]

model = LinearRegression()
model.fit(X,y)

hours = float(input("Enter how many hours you studied = "))

predicted_marks = model.predict([[hours]])

print(f"based on your hours {hours} yoou may score around{predicted_marks}")
# Out:
# based on your hours 10.0 yoou may score around[130.]
