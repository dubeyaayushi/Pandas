# %%
# Here we are gonna learn what is supervised learning

# !! Supervised ka matlab:- 
# Hum loog Machine ko sikhayenge using examples jinka already answer hai
 
#! Here we are gonna train our model for twwo things
# 1) To predict Numbers
# 2) Categories  perdiction like if someone is gonna pass or fail like in our project it will predict if the person is sick or not

# %%
# Now we are gonna learn about Regression
#! So Regression is basically used to predict a number 

# like we will predict how much marks a student would score by analyzing for how much hours he did the study

# we will predict the cost of a house by analyzing that how big the house is 

# ye ek linear relationship build karne ke liye use hota hai humare input and predicted output mein

# %%
# Now we are gonna learn about classification
#! So classfication predicts the category

# ya to pass ya to fail 

# ya to accha ya bura 

# either good or bad

# either male or female

# either rich or poor

# ya to image mein dog hogi ya cat


# ? yaha model 3 cheeze sekhta hai 

# ! 1) Logistic Regression
# ye output deta hai 0 ya ohir 1 mein basically sed for a yes or no problem 

# ! 2) K- Nearest Neighbours(KNN)
# K-Nearest Neighbors is also called as a lazy learner algorithm because it does not learn from the training set immediately instead it stores the entire dataset and performs computations only at the time of classification.

# For example, consider two features i.e Category 1 and Category 2:

# KNN assigns the category based on the majority of nearby points. The image shows how KNN predicts the category of a new data point based on its closest neighbours.
# The green points represent Category 1 and the red points represent Category 2.
# The new data point checks its closest neighbors (circled points).
# Since the majority of its closest neighbors are red points (Category 2) KNN predicts the new data point belongs to Category 2.

# ! Decision Tree Classifier
# it kind works like a if and else condition 
# Jaise if age above 18 hai to license  de do varna maat do

# %%
#! Now we are gonna learn how we Train our Model

#! So model training is done by 2 methods majorly 
# 1) .fit()
# 2) .predict()

#! 1) .fit()
# ismein hum loog humare data ke bsis pe apne model ko train karte hai 

# !2) .predict()
# iska matlab hota hai trained model ka use karke hum data nikalenge
