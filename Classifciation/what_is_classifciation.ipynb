# %%
Classification mein machine kuch examples se sekhti hai and phir try karti hai to classify new things into group 

now group could be labels or categories 

now the question is how our classification is different from regression 
so regression hamesha numbers predict karta hai jaise kise ke marks, salary, price etc
but classififcation labels predict kartaa hia jaise ki pass/fail , yes/no , spam/no spam etc

regression the output is continous 
but classification mein output ek fixed category hoti hai jaise ki ya to pass hoga ya fail hoga ya to low ya to high
