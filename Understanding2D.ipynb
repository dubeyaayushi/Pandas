# %%
#!         Undrstanding 2D flow in ML
        
#  !       🎯 Sabse Pehle Basic Baat

# Machine Learning me:

# X (input features) → hamesha 2D hota hai

# y (output/target) → usually 1D hota hai

# Ab sawal: 2D ka matlab kya?


#! 🧠 1D vs 2D Simple Example
# 🔹 1D Array (Sirf ek list)
# [5, 10, 15, 20]

# Ye sirf ek line hai.
# Isme rows ka concept nahi hai.


# !2D Array (Table jaisa)
# [[5],
#  [10],
#  [15],
#  [20]]

# Ye table jaisa hai:

#! Hours
# 5
# 10
# 15
# 20

#! 👉 Ye 4 rows aur 1 column hai.





#! 🎯 ML Ko 2D Kyun Chahiye?

# Machine Learning model sochta hai data ko is format me:

# [ [feature1, feature2, feature3],
#   [feature1, feature2, feature3],
#   [feature1, feature2, feature3] ]

# Matlab:

# Har row = ek student

# Har column = ek feature





#! 🔥 Example 1: Ek Feature (Hours)

# Agar sirf Hours hai:

# Hours
# 2
# 4
# 6

# To Python me:

# [[2],
#  [4],
#  [6]]

# Even though feature ek hi hai,
# phir bhi model ko table format chahiye.




# !🔥 Example 2: Do Features
# Hours	Sleep
# 2	6
# 4	7
# 6	8

# Python me:

# [[2, 6],
#  [4, 7],
#  [6, 8]]

# Ye clearly 2D hai.






#! 🚨 Tumhara Confusion Kahan Hota Hai?

# Yaha 👇

# model.predict(5)      ❌
# model.predict([5])    ❌
# model.predict([[5]])  ✅
# 🧠 Kyu [[5]]?

#! Model ko lagta hai:

# [ [Hours] ]

# Matlab:

# 1 row

# 1 feature

# Agar tum [5] dogi
# To model sochega:

# 5 rows? 1 feature?

# Wo confused ho jata hai 😅
